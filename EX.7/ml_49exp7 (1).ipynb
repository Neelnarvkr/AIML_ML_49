# %% [markdown]
# ## Name: Neel S Narvekar
# ### RollNo: 49
# #### Exp: 7              Date: 2|03|2026

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
data=fetch_california_housing()
print(data.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
x=pd.DataFrame(data.data,columns=data.feature_names)
y=data.target

print(x.head())
print("samples:",len(x))
print(y[:10])
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
# samples: 20640
# [4.526 3.585 3.521 3.413 3.422 2.697 2.992 2.414 2.267 2.611]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    x,y, test_size=0.3,random_state=42)

# %%
tree=DecisionTreeRegressor()
start=time.perf_counter()
tree.fit(X_train,Y_train)
tree_time=time.perf_counter()-start

pred_tree_test=tree.predict(X_test)
err_tree_=mean_absolute_error(Y_test,pred_tree_test)
pred_tree_train=tree.predict(X_train)
err_tree_train=mean_absolute_error(Y_train,pred_tree_train)

print("Decision Tree train MAE:",err_tree_train)
print("Decision Tree test MAE:",err_tree_test)
print("Decision Tree MAE:",tree_time)
# Out:
# Decision Tree train MAE: 4.3054952982937096e-17
# Decision Tree test MAE: 0.47085329780361757
# Decision Tree MAE: 0.1335694000008516

# %%
rf=RandomForestRegressor(n_estimators=100)
start=time.perf_counter()
rf.fit(X_train,Y_train)
rf_time=time.perf_counter()-start

pred_rf_test=tree.predict(X_test)
err_rf_test=mean_absolute_error(Y_test,pred_rf_test)
pred_rf_train=rf.predict(X_train)
err_rf_train=mean_absolute_error(Y_train,pred_rf_train)

print("Random Forest train MAE:",err_rf_train)
print("Random Forest test MAE:",err_rf_test)
print("Random Forest MAE:",rf_time)
# Out:
# Random Forest train MAE: 0.12443321306755299
# Random Forest test MAE: 0.47085329780361757
# Random Forest MAE: 9.665014899976086

# %%
gbr=GradientBoostingRegressor(n_estimators=1000000, learning_rate=0.1, max_depth=3)
start=time.perf_counter()
gbr.fit(X_train,Y_train)
gbr_time=time.perf_counter()-start

pred_gbr_test=gbr.predict(X_test)
err_gbr_test=mean_absolute_error(Y_test,pred_gbr_test)
pred_gbr_train=gbr.predict(X_train)
err_gbr_train=mean_absolute_error(Y_train,pred_gbr_train)

print("Gradient Boosting train MAE:",err_gbr_train)
print("Gradient Boosting test MAE:",err_gbr_test)
print("Gradient Boosting MAE:",gbr_time)

# %%
print("\n=====comparison for train=====")
print("Decision Tree train MAE:",err_tree_train)
print("Random Forest train MAE:",err_rf_train)
print("Gradient Boosting train MAE:",err_gbr_train)
# Out:
# =====comparison for train=====
# Decision Tree train MAE: 4.3054952982937096e-17
# Random Forest train MAE: 0.12409526035437471
# Gradient Boosting train MAE: 0.35577244047831796

# %%
print("\n=====comparison for test=====")
print("Decision Tree test MAE:",err_tree_test)
print("Random Forest test MAE:",err_rf_test)
print("Gradient Boosting test MAE:",err_gbr_test)
# Out:
# =====comparison for test=====
# Decision Tree test MAE: 0.47085329780361757
# Random Forest test MAE: 0.47085329780361757
# Gradient Boosting test MAE: 0.37143426460715595

# %%
print("\n=====comparison for time=====")
print("Decision Tree MAE:",tree_time)
print("Random Forest MAE:",rf_time)
print("Gradient Boosting MAE:",gbr_time)
# Out:
# =====comparison for time=====
# Decision Tree MAE: 0.1335694000008516
# Random Forest MAE: 9.499226099986117
# Gradient Boosting MAE: 3.417770300002303
